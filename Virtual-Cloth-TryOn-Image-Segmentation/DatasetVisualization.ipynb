# %% [markdown]
# # DATASET VISUALIZATION

# %%
import tensorflow as tf 
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
BATCH_SIZE = 32

# %%
trainDataset = tf.data.Dataset.load('SavedDataset/trainDataset')
valDataset = tf.data.Dataset.load('SavedDataset/valDataset')
# Out:
# 2025-02-08 09:03:46.821050: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-02-08 09:03:46.821073: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-02-08 09:03:46.821076: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-02-08 09:03:46.821089: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-02-08 09:03:46.821098: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
print(len(trainDataset)*BATCH_SIZE, len(valDataset)*BATCH_SIZE)
# Out:
# 928 96

# %%
#         R        G       B
MEAN = [123.675, 116.28, 103.53]
STD = [58.395, 57.12, 57.375]

# These Values Were Obtained From The ImageNet Dataset

# %%
plt.figure(figsize=(15, 10))
for data in valDataset.take(1):
    images, labels = data['pixel_values'], data['labels']
    for i in range(16):
        ax = plt.subplot(4, 4, i+1)
        if i%2==0:
            image = tf.transpose(images[i//2], (1, 2, 0))
            image = image * STD + MEAN
            plt.imshow(image)
            plt.title('Image')
        else:
            plt.imshow(labels[i//2])
            plt.title('Label')
        plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-7.6293945e-06..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-7.6293945e-06..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-7.6293945e-06..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-7.6293945e-06..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-7.6293945e-06..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-7.6293945e-06..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-7.6293945e-06..1.0].
# 2025-02-08 09:03:53.456552: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
