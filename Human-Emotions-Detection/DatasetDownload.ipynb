# %% [markdown]
# # DATASET DOWNLOAD

# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
# Out:
# mkdir: /Users/aman/.kaggle: File exists

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d muhammadhananasghar/human-emotions-datasethes
# Out:
# Dataset URL: https://www.kaggle.com/datasets/muhammadhananasghar/human-emotions-datasethes
# License(s): unknown
# ...
# 100%|███████████████████████████████████████▊| 308M/309M [00:03<00:00, 79.4MB/s]
# 100%|████████████████████████████████████████| 309M/309M [00:03<00:00, 91.4MB/s]

# %%
! unzip "/Users/aman/Documents/Work/Machine Learning/Computer-Vision-TensorFlow/Human-Emotions-Detection/human-emotions-datasethes.zip" -d "/Users/aman/Documents/Work/Machine Learning/Computer-Vision-TensorFlow/Human-Emotions-Detection/Dataset/"
# Out:
# Archive:  /Users/aman/Documents/Work/Machine Learning/Computer-Vision-TensorFlow/Human-Emotions-Detection/human-emotions-datasethes.zip
#   inflating: /Users/aman/Documents/Work/Machine Learning/Computer-Vision-TensorFlow/Human-Emotions-Detection/Dataset/Emotions Dataset/Emotions Dataset/test/angry/101071.jpg_rotation_1.jpg
#   inflating: /Users/aman/Documents/Work/Machine Learning/Computer-Vision-TensorFlow/Human-Emotions-Detection/Dataset/Emotions Dataset/Emotions Dataset/test/angry/101810.jpg_brightness_1.jpg
#   inflating: /Users/aman/Documents/Work/Machine Learning/Computer-Vision-TensorFlow/Human-Emotions-Detection/Dataset/Emotions Dataset/Emotions Dataset/test/angry/101810.jpg_rotation_1.jpg
#   inflating: /Users/aman/Documents/Work/Machine Learning/Computer-Vision-TensorFlow/Human-Emotions-Detection/Dataset/Emotions Dataset/Emotions Dataset/test/angry/103108.jpg_brightness_2.jpg
# ...
