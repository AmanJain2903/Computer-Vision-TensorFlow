# %% [markdown]
# # HYPERPARAMTER TUNING USING TENSORBOARD

# %%
# Import Depedencies
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tensorboard import notebook
import datetime
import tensorflow_datasets as tfds
from tensorflow.keras.layers import Input, Normalization, Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TrueNegatives, TruePositives, Precision, Recall, F1Score, AUC
from tensorflow.keras.regularizers import L2
from tensorboard.plugins.hparams import api as hp
import random

# %%
# Load Malaria Dataset From Tensorflow Datasets
dataset, datasetInfo = tfds.load("malaria", 
                                 with_info=True, 
                                 shuffle_files=True) # -----------++++++    ->    ---+++-++--+++-

# Dataset Split Function
def split(dataset, TRAIN_RATIO, VAL_RATIO, TEST_RATIO):
    trainDataset = dataset.take(int(TRAIN_RATIO*len(dataset)))
    leftDataset = dataset.skip(int(TRAIN_RATIO*len(dataset)))
    valDataset = leftDataset.take(int(VAL_RATIO*len(dataset)))
    testDataset = leftDataset.skip(int(VAL_RATIO*len(dataset)))
    return trainDataset, valDataset, testDataset

# Split Dataset As 80/10/10 
TRAIN_RATIO = 0.8
VAL_RATIO = 0.1
TEST_RATIO = 0.1
trainDataset, valDataset, testDataset = split(dataset['train'], TRAIN_RATIO, VAL_RATIO, TEST_RATIO)

IMAGE_SIZE = 224
def resizeRescale(inputs):
    return tf.image.resize(inputs['image'], (IMAGE_SIZE, IMAGE_SIZE))/255., inputs['label']
trainDataset = trainDataset.map(resizeRescale)
valDataset = valDataset.map(resizeRescale)
testDataset = testDataset.map(resizeRescale)

# Dataset Batching
BATCH_SIZE=32
BUFFER_SIZE = 8
trainDataset = trainDataset.shuffle(buffer_size=BUFFER_SIZE, reshuffle_each_iteration=True).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
valDataset = valDataset.shuffle(buffer_size=BUFFER_SIZE, reshuffle_each_iteration=True).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
testDataset = testDataset.shuffle(buffer_size=BUFFER_SIZE, reshuffle_each_iteration=True).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-01-26 09:47:10.419288: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-01-26 09:47:10.419315: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-01-26 09:47:10.419318: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-01-26 09:47:10.419334: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-01-26 09:47:10.419345: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## MODEL TUNE FUNCTION

# %%
def modelTune(hparams):
    # Using Sequential API with Hyperparamters
    IMAGE_SIZE = 224
    model = tf.keras.Sequential([
        Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3)),

        Conv2D(filters=6, kernel_size=3, strides=1, padding='valid', activation='relu', kernel_regularizer=L2(hparams[HP_REGULARIZATION_RATE])),
        BatchNormalization(),
        MaxPooling2D(pool_size=2, strides=2),
        Dropout(rate = hparams[HP_DROPOUT_RATE]),

        Conv2D(filters=16, kernel_size=3, strides=1, padding='valid', activation='relu', kernel_regularizer=L2(hparams[HP_REGULARIZATION_RATE])),
        BatchNormalization(),
        MaxPooling2D(pool_size=2, strides=2),

        Flatten(),

        Dense(hparams[HP_NUM_UNITS_1], activation='relu', kernel_regularizer=L2(hparams[HP_REGULARIZATION_RATE])),
        BatchNormalization(),
        Dropout(rate = hparams[HP_DROPOUT_RATE]),

        Dense(hparams[HP_NUM_UNITS_2], activation='relu', kernel_regularizer=L2(hparams[HP_REGULARIZATION_RATE])),
        BatchNormalization(),
        Dropout(rate = hparams[HP_DROPOUT_RATE]),

        Dense(1, activation='sigmoid'),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=hparams[HP_LEARNING_RATE]),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=['accuracy']
    )

    model.fit(trainDataset, epochs=1)
    _, accuracy = model.evaluate(valDataset)
    return accuracy

# %% [markdown]
# ## HYPER-PARAMETERS RANGE

# %%
HP_NUM_UNITS_1 = hp.HParam('NUM_UNITS_1', hp.Discrete([16, 32, 64, 128]))
HP_NUM_UNITS_2 = hp.HParam('NUM_UNITS_2', hp.Discrete([16, 32, 64, 128]))
HP_DROPOUT_RATE = hp.HParam('DROPOUT_RATE', hp.Discrete([0.1, 0.2, 0.3]))
HP_REGULARIZATION_RATE = hp.HParam('REGULARIZATION', hp.Discrete([0.001, 0.01, 0.1]))
HP_LEARNING_RATE = hp.HParam('LEARNING_RATE', hp.Discrete([1e-4, 1e-3]))

# %% [markdown]
# ## GRID SEARCH METHOD TO TUNE
# ### -> Very slow but better results

# %%
runNumber = 0
for NUM_UNITS_1 in HP_NUM_UNITS_1.domain.values:
    for NUM_UNITS_2 in HP_NUM_UNITS_2.domain.values:
        for DROPOUT_RATE in HP_DROPOUT_RATE.domain.values:
            for REGULARIZATION_RATE in HP_REGULARIZATION_RATE.domain.values:
                for LEARNING_RATE in HP_LEARNING_RATE.domain.values:
                    hparams = {
                        HP_NUM_UNITS_1 : NUM_UNITS_1,
                        HP_NUM_UNITS_2 : NUM_UNITS_2,
                        HP_DROPOUT_RATE : DROPOUT_RATE,
                        HP_REGULARIZATION_RATE : REGULARIZATION_RATE,
                        HP_LEARNING_RATE : LEARNING_RATE
                    }

                    fileWriter = tf.summary.create_file_writer('logs/HParamsTuning/' + str(runNumber+1))

                    with fileWriter.as_default():
                        hp.hparams(hparams)
                        accuracy = modelTune(hparams)
                        tf.summary.scalar('accuracy', data = accuracy, step = runNumber+1)
                    print("For Run : {}, Our Hyper-Parameters are : \n NUM_UNITS_1 : {}\n NUM_UNITS_2 : {}\n DROPOUT_RATE : {}\n REGULARIZATION_RATE : {}\n LEARNING_RATE : {}\n".format(runNumber+1, hparams[HP_NUM_UNITS_1], hparams[HP_NUM_UNITS_2], hparams[HP_DROPOUT_RATE], hparams[HP_REGULARIZATION_RATE], hparams[HP_LEARNING_RATE]))
                    runNumber+=1

# %% [markdown]
# ## RANDOM SEARCH METHOD TO TUNE
# ### -> Faster but not that good results

# %%
# Convert hyperparameter ranges to lists
NUM_UNITS_1_list = HP_NUM_UNITS_1.domain.values
NUM_UNITS_2_list = HP_NUM_UNITS_2.domain.values
DROPOUT_RATE_list = HP_DROPOUT_RATE.domain.values
REGULARIZATION_RATE_list = HP_REGULARIZATION_RATE.domain.values
LEARNING_RATE_list = HP_LEARNING_RATE.domain.values

nRandomSearches = 100
# Perform random search
runNumber = 0
for _ in range(nRandomSearches):
    # Randomly sample hyperparameters
    hparams = {
        HP_NUM_UNITS_1: random.choice(NUM_UNITS_1_list),
        HP_NUM_UNITS_2: random.choice(NUM_UNITS_2_list),
        HP_DROPOUT_RATE: random.choice(DROPOUT_RATE_list),
        HP_REGULARIZATION_RATE: random.choice(REGULARIZATION_RATE_list),
        HP_LEARNING_RATE: random.choice(LEARNING_RATE_list)
    }

    fileWriter = tf.summary.create_file_writer(f'logs/HParamsTuning/{runNumber+1}')

    with fileWriter.as_default():
        hp.hparams(hparams)
        accuracy = modelTune(hparams)
        tf.summary.scalar('accuracy', data=accuracy, step=runNumber+1)

    print(f"Run {runNumber+1}: Hyperparameters are:")
    print(f"  NUM_UNITS_1: {hparams[HP_NUM_UNITS_1]}")
Hyperparameters are:
#   NUM_UNITS_1: 64
#   NUM_UNITS_2: 64
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 48s 64ms/step - accuracy: 0.6413 - loss: 3.4572
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5803 - loss: 1.8419
# Run 73: Hyperparameters are:
#   NUM_UNITS_1: 128
#   NUM_UNITS_2: 128
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 56s 76ms/step - accuracy: 0.6199 - loss: 2.0488
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6452 - loss: 1.2438
# Run 74: Hyperparameters are:
#   NUM_UNITS_1: 64
#   NUM_UNITS_2: 32
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 49s 66ms/step - accuracy: 0.6104 - loss: 0.8945
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6628 - loss: 0.8824
# Run 75: Hyperparameters are:
#   NUM_UNITS_1: 128
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 46s 62ms/step - accuracy: 0.6344 - loss: 1.7475
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.5138 - loss: 1.0574
# Run 76: Hyperparameters are:
#   NUM_UNITS_1: 64
#   NUM_UNITS_2: 128
#   DROPOUT_RATE: 0.3
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 43s 58ms/step - accuracy: 0.6272 - loss: 1.2711
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5846 - loss: 1.0528
# Run 77: Hyperparameters are:
#   NUM_UNITS_1: 16
#   NUM_UNITS_2: 32
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 44s 59ms/step - accuracy: 0.6425 - loss: 0.8189
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5593 - loss: 0.9397
# Run 78: Hyperparameters are:
#   NUM_UNITS_1: 32
#   NUM_UNITS_2: 128
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 45s 60ms/step - accuracy: 0.6349 - loss: 3.4663
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6299 - loss: 1.1242
# Run 79: Hyperparameters are:
#   NUM_UNITS_1: 32
#   NUM_UNITS_2: 64
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.1
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 44s 58ms/step - accuracy: 0.6275 - loss: 0.7411
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5464 - loss: 0.7996
# Run 80: Hyperparameters are:
#   NUM_UNITS_1: 16
#   NUM_UNITS_2: 64
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 49s 66ms/step - accuracy: 0.6038 - loss: 0.9931
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5500 - loss: 0.9217
# Run 81: Hyperparameters are:
#   NUM_UNITS_1: 128
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.3
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 49s 66ms/step - accuracy: 0.6407 - loss: 0.9524
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5512 - loss: 0.9810
# Run 82: Hyperparameters are:
#   NUM_UNITS_1: 128
#   NUM_UNITS_2: 64
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 43s 57ms/step - accuracy: 0.6184 - loss: 1.2530
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5649 - loss: 1.0538
# Run 83: Hyperparameters are:
#   NUM_UNITS_1: 16
#   NUM_UNITS_2: 32
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 49s 65ms/step - accuracy: 0.6618 - loss: 1.0233
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7038 - loss: 0.8509
# Run 84: Hyperparameters are:
#   NUM_UNITS_1: 128
#   NUM_UNITS_2: 128
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 46s 61ms/step - accuracy: 0.6251 - loss: 1.5917
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5767 - loss: 1.0936
# Run 85: Hyperparameters are:
#   NUM_UNITS_1: 64
#   NUM_UNITS_2: 64
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 49s 66ms/step - accuracy: 0.6390 - loss: 10.5085
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6552 - loss: 2.4103
# Run 86: Hyperparameters are:
#   NUM_UNITS_1: 128
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.1
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 43s 57ms/step - accuracy: 0.6119 - loss: 8.1873
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5714 - loss: 3.2289
# Run 87: Hyperparameters are:
#   NUM_UNITS_1: 32
#   NUM_UNITS_2: 128
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.1
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 43s 58ms/step - accuracy: 0.6084 - loss: 5.8661
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5300 - loss: 2.6105
# Run 88: Hyperparameters are:
#   NUM_UNITS_1: 32
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.1
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 44s 59ms/step - accuracy: 0.6078 - loss: 0.8262
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6095 - loss: 0.7778
# Run 89: Hyperparameters are:
#   NUM_UNITS_1: 32
#   NUM_UNITS_2: 32
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 49s 65ms/step - accuracy: 0.6214 - loss: 1.0062
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6476 - loss: 0.8489
# Run 90: Hyperparameters are:
#   NUM_UNITS_1: 128
#   NUM_UNITS_2: 32
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 45s 59ms/step - accuracy: 0.6192 - loss: 9.0172
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5850 - loss: 3.2818
# Run 91: Hyperparameters are:
#   NUM_UNITS_1: 64
#   NUM_UNITS_2: 32
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.1
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 64s 63ms/step - accuracy: 0.5645 - loss: 2.3592
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5132 - loss: 0.8696
# Run 92: Hyperparameters are:
#   NUM_UNITS_1: 16
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.1
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 46s 61ms/step - accuracy: 0.6179 - loss: 1.4937
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5440 - loss: 1.3429
# Run 93: Hyperparameters are:
#   NUM_UNITS_1: 32
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 48s 65ms/step - accuracy: 0.6089 - loss: 0.9256
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6436 - loss: 0.8684
# Run 94: Hyperparameters are:
#   NUM_UNITS_1: 128
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 46s 61ms/step - accuracy: 0.5869 - loss: 3.7691
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5582 - loss: 1.2063
# Run 95: Hyperparameters are:
#   NUM_UNITS_1: 64
#   NUM_UNITS_2: 32
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.1
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 45s 59ms/step - accuracy: 0.6775 - loss: 2.6152
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7970 - loss: 1.0069
# Run 96: Hyperparameters are:
#   NUM_UNITS_1: 32
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.1
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 45s 60ms/step - accuracy: 0.6650 - loss: 0.8373
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5779 - loss: 0.8798
# Run 97: Hyperparameters are:
#   NUM_UNITS_1: 64
#   NUM_UNITS_2: 64
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.001
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 46s 61ms/step - accuracy: 0.6280 - loss: 1.8190
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6484 - loss: 1.1064
# Run 98: Hyperparameters are:
#   NUM_UNITS_1: 64
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.2
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.0001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 51s 68ms/step - accuracy: 0.6043 - loss: 1.7608
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.5040 - loss: 1.0603
# Run 99: Hyperparameters are:
#   NUM_UNITS_1: 128
#   NUM_UNITS_2: 32
#   DROPOUT_RATE: 0.3
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.001
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 44s 58ms/step - accuracy: 0.5759 - loss: 1.5196
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5437 - loss: 1.1420
# Run 100: Hyperparameters are:
#   NUM_UNITS_1: 32
#   NUM_UNITS_2: 16
#   DROPOUT_RATE: 0.1
#   REGULARIZATION_RATE: 0.01
#   LEARNING_RATE: 0.0001

# %%
notebook.start("--logdir logs")
# Out:
# Reusing TensorBoard on port 6007 (pid 38203), started 15:17:02 ago. (Use '!kill 38203' to kill it.)
#       <iframe id="tensorboard-frame-7bf1efbf880676ca" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7bf1efbf880676ca");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
